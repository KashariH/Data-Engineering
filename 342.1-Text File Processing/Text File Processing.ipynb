# %% [markdown]
# # `Text File Processing`

# %% [markdown]
# # `Learning Objective` : Read and Write data to text file. Explore how to open and close files in Python effectively. Describe the absolute path and relative path. Identify the Python File Modes. Write a list to a file using a Loop.

# %% [markdown]
# ### What is a File? A File is a named location on a storage device that contains data. Files can be different types such as, text files, binary files, and images.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### File handling is the process of performing operations on files, such as reading, writing, and deleting.

# %% [markdown]
# ### Types of File: Text file ( Text file usually we use to store character data. For example, text.txt) Binary File( The binary files are used to store binary data such as images, video files, audio files, etc.)

# %% [markdown]
# # `File Path`

# %% [markdown]
# ### A file path define the lo of a file or folder in the computer system.

# %% [markdown]
# ### There are two ways to specify a file path. 1. Absolute path (Always begin with the root folder)  2. Relative path (Relative to the program's current directory)

# %% [markdown]
# ## `File Handling Operations`

# %% [markdown]
# ### Python gives functions and modules for working with files.

# %% [markdown]
# ### If you have a code and the slash is going one way from the file slash input a raw string (r') to correct the error.

# %% [markdown]
# ### You use the "with" statement for file handling and the modes ("a" for append, "r" for read.)

# %% [markdown]
# #### When there is "response" that means it is a JSON object.
