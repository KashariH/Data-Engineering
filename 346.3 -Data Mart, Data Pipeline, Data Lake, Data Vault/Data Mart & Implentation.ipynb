# %% [markdown]
# # `Data Mart`

# %% [markdown]
# ### A data mart is a simple form of data warehouse focused on a single subject or line of business. A data mart is a subset of data, whereas a data warehouse is a mega-mart.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Data Warehouse Vs Data Mart Comparison Chart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # `Implementing Data Mart`

# %% [markdown]
# ### Step 1: Design, Step 2: Construct, Step 3: Populate, Step 4: Access, Step 5: Manage

# %% [markdown]
# # `Types of data marts`

# %% [markdown]
# ### There are three types of data marts that differ based on their relationship to the data warehouse and the respective data sources of eac
