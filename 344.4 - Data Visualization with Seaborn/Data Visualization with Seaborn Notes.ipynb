# %% [markdown]
# ### `Data Visualization with Seaborn Notes`

# %% [markdown]
# ##### Seaborn is another data visualization library, built on top of Matplotlib. Seaborn offers a range of built-in themes and colors palettes that improve the visual appeal of your plots with minimal effort.

# %% [markdown]
# ##### The key benefit of Seaborn is its ability to create visually appealing plots with minimal code. With seaborn, you can generate plots using five times less code compared to Matplotlib.

# %% [markdown]
# ##### Seaborn integrates well with statistical libraries such as NumpPy & SciPy, allowing you to easily combine statistical analysis with visualizations.

# %% [markdown]
# ##### Seaborn works well with Pandas DataFrames so you can load your data into a df using Pandas.

# %% [markdown]
# ##### Choose a plot type: Seaborn provides a variety of plot types for different kinds of data and visualization needs. Some popular plot types include scatter plots, line plots, bar plots, histograms, and heatmaps.

# %% [markdown]
# ##### Customize your plot (optional): Seaborn allows for extensive customization of plots to meet your specific requirements. You can adjust colors, styles, axis labels, titles, and more.

# %% [markdown]
# ##### Show or save your plot: Once your plot is ready, you can display it directly in your python environment or save it to a file for later use.

# %% [markdown]
# ##### You can import Seaborn in your python script as (import seaborn as sns) as well as (import seaborn.objects as so)

# %%
import seaborn as sns # Import seaborn for data visualization
df = sns.load_dataset("penguins") # Load the penguins dataset
sns.pairplot(df, hue="species") # Create a pairplot of the dataset, colored by species

# %% [markdown]
# ##### `Seaborn Plot Types`

# %% [markdown]
# ##### Seaborn offers a diverse range of plot types for data visualization and exploratory data analysis. These visualizations can broadly fall into one of the three categories:

# %% [markdown]
# ##### Univariate - Utilizing only one axis of information (x).

# %% [markdown]
# ##### Bivariate - Utilizing two axes of information (x and y).

# %% [markdown]
# ##### Trivariate - Utilizing three axes of information (x, y, & z)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### `Seaborn Functions`

# %% [markdown]
# ##### The seaborn functions for the plots are categorized into six categories as shown below.

# %% [markdown]
# ![Screenshot 2025-05-13 095128.png](<attachment:Screenshot 2025-05-13 095128.png>)

# %% [markdown]
# ##### `Common List Seaborn Functions`

# %% [markdown]
# ##### Scatter Plot - Seaborn's scatterplot() function provides a simple way to create scatter plots.

# %% [markdown]
# ##### Line plot - Seaborn's lineplot() function provides a simple way to create line plots.

# %% [markdown]
# ##### Histogram - Seaborn's histplot() function provides a simple way to create histograms.

# %% [markdown]
# ##### Box plot - Seaborn's boxplot() function provides a simple way to create box plots.

# %% [markdown]
# ##### Heatmap - Seaborn's heatmap() function provides a simple way to create heatmaps.

# %% [markdown]
# ##### Pairplot - Seaborn's pairplot() function provides a simple way to create pairplots.

# %% [markdown]
# ##### Linear Regression - seaborn.regplot() function is used to plot data and draw a linear regression model.

# %% [markdown]
# ##### fit & seaborn - residplot() function uses to plot residual data of a linear regression.

# %% [markdown]
# ##### Density plots - kdeplot() function uses to plot univariate or bivariate plots using kernel density.

# %% [markdown]
# ##### `Load_database() method in Seaborn`

# %% [markdown]
# ##### The load_dataset method is used to load built-in datasets from the Seaborn library, allowing users to load sample datasets directly into their python environ. These datasets are often used for demonstration purposes and can be conveniently accessed for practicing data visualization with Seaborn. The function returns a Pandas DataFrame containing the specified dataset.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### `Seaborn vs. Matplotlib`

# %% [markdown]
# ##### Seaborn is built on top of Matplotlib and provides a higher-level interface for creating statistical graphics. While Matplotlib is a general-purpose plotting library, Seaborn is specifically designed for statistical data visualization.

# %% [markdown]
# ##### Seaborn offers several disadvantages over Matplotlib, including simpler syntax for creating complex plots, built-in support for statistical visualizations, and aesthetically pleasing default settings that can be easily customized.
