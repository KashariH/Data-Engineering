# %% [markdown]
# ### `Learning Objective - 344.3`

# %% [markdown]
# #### Scatter Plots

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Bar Chart

# %% [markdown]
# ![image.png](attachment:image.png)
